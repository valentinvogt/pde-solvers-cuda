# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset("data/example.nc")

# %%
data = ds["initial_data"]
u = u0 = data[0, :, 0::2].values

# %%
plt.imshow(u)
